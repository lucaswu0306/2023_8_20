# %%
import numpy as np
index = np.arange(5)
value = np.array([5,7,3,4,6])*1000
import matplotlib.pyplot as plt
figure = plt.figure(figsize=(8,5))
axes = figure.add_subplot()
axes.bar(index,value)
axes.set_xticks(index,['apple','orange','potato','banana','guava'])
axes.grid(axis='y')
xmin,xmax,ymin,ymax= axes.axis()
print(xmin,xmax,ymin,ymax)
#axes.axis([xmin-1, xmax+1, ymin, ymax+1000])#讓x軸的範圍變大
for i in index:
    print(i,value[i],end=' ')
    axes.annotate(str(value[i]),[i-0.18,value[i]+100])
    
    
plt.show()
# Out:
# -0.6400000000000001 4.640000000000001 0.0 7350.0
# 0 5000 1 7000 2 3000 3 4000 4 6000

# %%
import pandas as pd
series_dict = pd.Series(data=[1,2,3,4,5],index=['a','b','c','d','e'])
series_dict
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
series_dict = pd.Series(data=[45,92,65,82,47],index=['國文','英文','數學','自然','社會'])
series_dict
# Out:
# 國文    45
# 英文    92
# 數學    65
# 自然    82
# 社會    47
# dtype: int64

# %%
#Series,values,index
series_dict.values#int64 代表64位元的數值範圍值
series_dict.index
series_dict +=3#陣列運算
series_dict
# Out:
# 國文    48
# 英文    95
# 數學    68
# 自然    85
# 社會    50
# dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd
sdata = pd.Series({'Taipei':35000, 'Taoyuan':71000, 'Taichung':16000, 'Kaohsiung':5000})
figure = plt.figure(figsize=(8,5))
axes = figure.add_subplot()
axes.bar(sdata.index,sdata.values)
axes.grid(axis='y')
xmin,xmax,ymin,ymax=axes.axis()
#print(xmin,xmax,ymin,ymax)
axes.axis([xmin-1,xmax+1,ymin,ymax])
plt.show()

# %%
sdata = pd.Series({'Taipei':35000, 'Taoyuan':71000, 'Taichung':16000, 'Kaohsiung':5000})
sdata
# Out:
# Taipei       35000
# Taoyuan      71000
# Taichung     16000
# Kaohsiung     5000
# dtype: int64
