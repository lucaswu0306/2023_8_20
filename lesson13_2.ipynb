# %%
ur1 = 'https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=rdec-key-123-45678-011121314&format=JSON'

# %%
import requests
requests.request(method, url, **kwargs)#**星星可以省略傳入引數

# %%
import requests
response = requests.get(ur1)
print(response)
# Out:
# <Response [200]>

# %%
if response.status_code == 200:
    print("下載成功")
    print(response.text)#純文字檔(property)text: str(儲存在字串的記憶體當中)
# Out:
# 下載成功
# {
#  "cwbopendata": {
#   "@xmlns": "urn:cwb:gov:tw:cwbcommon:0.1",
#   "identifier": "ed6fb46f-cb63-6871-e321-93e415105b72",
#   "sender": "weather@cwb.gov.tw",
#   "sent": "2023-09-08T11:15:02+08:00",
#   "status": "Actual",
#   "msgType": "Issue",
#   "source": "MFC",
#   "dataid": "C0032-001",
#   "scope": "Public",
#   "dataset": {
#    "datasetInfo": {
#     "datasetDescription": "三十六小時天氣預報",
#     "issueTime": "2023-09-08T11:00:00+08:00",
#     "update": "2023-09-08T11:15:02+08:00"
#    },
#    "location": [
#     {
#      "locationName": "臺北市",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲",
#           "parameterValue": "4"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲",
#           "parameterValue": "4"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲",
#           "parameterValue": "4"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "29",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "31",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "24",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "24",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     },
#     {
#      "locationName": "新北市",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲短暫陣雨或雷雨",
#           "parameterValue": "15"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲",
#           "parameterValue": "4"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲",
#           "parameterValue": "4"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "29",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "31",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "24",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "24",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     },
#     {
#      "locationName": "桃園市",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲短暫陣雨或雷雨",
#           "parameterValue": "15"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲",
#           "parameterValue": "4"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲",
#           "parameterValue": "4"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "32",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "24",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "24",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     },
#     {
#      "locationName": "臺中市",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "陰時多雲短暫陣雨或雷雨",
#           "parameterValue": "17"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "晴時多雲",
#           "parameterValue": "2"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲短暫陣雨或雷雨",
#           "parameterValue": "15"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "31",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "29",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "32",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "29",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "26",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "26",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "50",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     },
#     {
#      "locationName": "臺南市",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "陰短暫陣雨或雷雨",
#           "parameterValue": "18"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "陰短暫陣雨或雷雨",
#           "parameterValue": "18"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "陰時多雲短暫陣雨或雷雨",
#           "parameterValue": "17"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "29",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "28",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "29",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "28",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "26",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "26",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "60",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "50",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     },
#     {
#      "locationName": "高雄市",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "陰短暫陣雨或雷雨",
#           "parameterValue": "18"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "陰短暫陣雨或雷雨",
#           "parameterValue": "18"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "陰短暫陣雨或雷雨",
#           "parameterValue": "18"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "29",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "28",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "29",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "28",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "26",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "26",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "70",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "60",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     },
#     {
#      "locationName": "基隆市",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "晴時多雲",
#           "parameterValue": "2"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "晴時多雲",
#           "parameterValue": "2"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "晴時多雲",
#           "parameterValue": "2"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "28",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "29",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "25",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "25",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     },
#     {
#      "locationName": "新竹縣",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲短暫陣雨或雷雨",
#           "parameterValue": "15"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲",
#           "parameterValue": "4"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲",
#           "parameterValue": "4"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "28",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "32",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "28",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "25",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "25",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     },
#     {
#      "locationName": "新竹市",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "陰時多雲短暫陣雨或雷雨",
#           "parameterValue": "17"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲",
#           "parameterValue": "4"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲",
#           "parameterValue": "4"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "28",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "31",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "28",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "25",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "25",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     },
#     {
#      "locationName": "苗栗縣",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "陰天",
#           "parameterValue": "7"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲短暫陣雨或雷雨",
#           "parameterValue": "15"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲短暫陣雨或雷雨",
#           "parameterValue": "15"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "29",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "32",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "29",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "26",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "26",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     },
#     {
#      "locationName": "彰化縣",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲短暫陣雨或雷雨",
#           "parameterValue": "15"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "晴時多雲",
#           "parameterValue": "2"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲短暫陣雨或雷雨",
#           "parameterValue": "15"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "28",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "31",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "28",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "25",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "25",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     },
#     {
#      "locationName": "南投縣",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "陰短暫陣雨或雷雨",
#           "parameterValue": "18"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲短暫陣雨或雷雨",
#           "parameterValue": "15"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲短暫陣雨或雷雨",
#           "parameterValue": "15"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "31",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "28",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "31",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "28",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "25",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "25",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "70",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     },
#     {
#      "locationName": "雲林縣",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "陰短暫陣雨或雷雨",
#           "parameterValue": "18"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "晴時多雲",
#           "parameterValue": "2"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲短暫陣雨或雷雨",
#           "parameterValue": "15"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "25",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "25",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "70",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
# ...
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "60",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     },
#     {
#      "locationName": "臺東縣",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "陰短暫陣雨",
#           "parameterValue": "11"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "陰時多雲短暫陣雨",
#           "parameterValue": "10"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲短暫陣雨或雷雨",
#           "parameterValue": "15"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "29",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "29",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "25",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "25",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "80",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "50",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     },
#     {
#      "locationName": "澎湖縣",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲時陰短暫陣雨或雷雨",
#           "parameterValue": "16"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "陰短暫陣雨或雷雨",
#           "parameterValue": "18"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲時陰短暫陣雨或雷雨",
#           "parameterValue": "16"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "25",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "25",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "60",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "30",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     },
#     {
#      "locationName": "金門縣",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "陰天",
#           "parameterValue": "7"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "多雲",
#           "parameterValue": "4"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "晴時多雲",
#           "parameterValue": "2"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "29",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "29",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "26",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "26",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     },
#     {
#      "locationName": "連江縣",
#      "weatherElement": [
#       {
#        "elementName": "Wx",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "晴時多雲",
#           "parameterValue": "2"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "晴時多雲",
#           "parameterValue": "2"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "晴時多雲",
#           "parameterValue": "2"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MaxT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "28",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "28",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "MinT",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "27",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "26",
#           "parameterUnit": "C"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "26",
#           "parameterUnit": "C"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "CI",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "舒適至悶熱"
#          }
#         }
#        ]
#       },
#       {
#        "elementName": "PoP",
#        "time": [
#         {
#          "startTime": "2023-09-08T12:00:00+08:00",
#          "endTime": "2023-09-08T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-08T18:00:00+08:00",
#          "endTime": "2023-09-09T06:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         },
#         {
#          "startTime": "2023-09-09T06:00:00+08:00",
#          "endTime": "2023-09-09T18:00:00+08:00",
#          "parameter": {
#           "parameterName": "20",
#           "parameterUnit": "百分比"
#          }
#         }
#        ]
#       }
#      ]
#     }
#    ]
#   }
#  }
# }
